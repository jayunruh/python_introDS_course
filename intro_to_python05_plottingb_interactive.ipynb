# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objs as go
import webbrowser
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
df = pd.read_csv('https://www.dropbox.com/s/czjccph6bto67ge/Compositions.csv?dl=1')
df = df.fillna(1)
df['SqrtViews'] = np.power(df['Views'],.5)

# %%
df
# Out:
#      Year Completed                        Composition Opus      Type  \
# 0              1800                         Symphony 1   21  Symphony
# 1              1802                         Symphony 2   36  Symphony
# 2              1803                         Symphony 3   55  Symphony
# 3              1806                         Symphony 4   60  Symphony
# 4              1808                         Symphony 5   67  Symphony
# ..              ...                                ...  ...       ...
# 122            1807                    Mass in C major   86    Choral
# 123            1809            Choral Fantasy, C minor   80    Choral
# 124            1814          Der glorreiche Augenblick  136    Choral
# 125            1815  Meeresstille und gluckliche Fahrt  112    Choral
# 126            1823                     Missa solemnis  123    Choral
#
#          Views                                         Link     SqrtViews
# ...

# %%
f=go.FigureWidget(
    px.bar(df, x='Year Completed', y='SqrtViews', color='Type', hover_data=['Composition', 'Link'], height=600, title='Popularity of Beethoven Compositions')
    )

def click_fn(trace, points, state):
    
    if (len(points.point_inds)>0):
        link = (f.data[points.trace_index]['customdata'][points.point_inds[-1]])[1]
        print(link)
        if (isinstance(link, str)):
            webbrowser.open(link) 

for a in f.data:
    a.on_click(click_fn)

f
# Out:
# FigureWidget({
#     'data': [{'alignmentgroup': 'True',
#               'customdata': array([['Symphony 1', 'https://www.youtube.com/watch?v=I1rA68yF4tM'],
#                                    ['Symphony 2', 'https://www.youtube.com/watch?v=bEiYmeeV6sI'],
#                                    ['Symphony 3', 'https://www.youtube.com/watch?v=fhHcty9OM-0'],
#                                    ['Symphony 4', 'https://www.youtube.com/watch?v=7fQ2OWWzHZ8'],
#                                    ['Symphony 5', 'https://www.youtube.com/watch?v=jv2WJMVPQi8'],
#                                    ['Symphony 6', 'https://www.youtube.com/watch?v=aW-7CqxhnAQ'],
#                                    ['Symphony 7', 'https://www.youtube.com/watch?v=-4788Tmz9Zo&t=3s'],
#                                    ['Symphony 8', 'https://www.youtube.com/watch?v=V6set4KUs4w&t=832s'],
#                                    ['Symphony 9', 'https://www.youtube.com/watch?v=rOjHhS5MtvA']],
# ...
